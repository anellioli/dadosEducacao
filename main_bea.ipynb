# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Limpeza dos Dados

# %%
df = pd.read_excel('Sinopse_Estatistica_2022.xlsx',sheet_name = 8)

# %%
df.head(20)
# Out:
#                                     Voltar ao Sumário            Unnamed: 1  \
# 0                                          MATRÍCULAS                   NaN
# 1                                     Educação Básica                   NaN
# 2   1.3 – Número de Matrículas da Educação Básica,...                   NaN
# 3                                                 NaN                   NaN
# 4                                   Região Geográfica  Unidade da Federação
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                             Brasil
# 10                                             Norte
# 11                                             Norte              Rondônia
# ...

# %%
#escluindo linhas vazias
df = df.drop([0,1,2,3,4,5,6,7,8,5612, 5613, 5614, 5615, 5616, 5617],0)
# Out:
# C:\Users\beatr\AppData\Local\Temp/ipykernel_21736/1904671301.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop([0,1,2,3,4,5,6,7,8,5612, 5613, 5614, 5615, 5616, 5617],0)

# %%
#renomeando as colunas
df1 = df1.set_axis(["Regiao_Geografica","Unidade_da_Federacao","Municipio", "Codigo_do_Municipio", "Matriculas_Total", "Matriculas_Fem_Total", "MF_Nao_Declarada", "MF_Branca", "MF_Preta", "MF_Parda", "MF_Amarela", "MF_Indigena","Matriculas_Masc_Total", "MM_Nao_Declarada", "MM_Branca", "MM_Preta", "MM_Parda", "MM_Amarela", "MM_Indigena"],axis=1)

# %%
#excoluindo linhas com valores totais
df2 = df1.query(" Municipio != '  '")

# %%
#resetando o index
df2.reset_index(drop = True)
# Out:
#      Regiao_Geografica Unidade_da_Federacao                 Municipio  \
# 0               Norte             Rondônia     Alta Floresta D'Oeste
# 1               Norte             Rondônia   Alto Alegre dos Parecis
# 2               Norte             Rondônia              Alto Paraíso
# 3               Norte             Rondônia          Alvorada D'Oeste
# 4               Norte             Rondônia                 Ariquemes
# ...                ...                  ...                       ...
# 5565     Centro-Oeste                Goiás                Vianópolis
# 5566     Centro-Oeste                Goiás            Vicentinópolis
# 5567     Centro-Oeste                Goiás                  Vila Boa
# 5568     Centro-Oeste                Goiás             Vila Propício
# 5569     Centro-Oeste     Distrito Federal                  Brasília
#
#      Codigo_do_Municipio Matriculas_Total Matriculas_Fem_Total  \
# 0                1100015             5060                 2493
# ...

# %% [markdown]
# ## Informações gerais da base

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 12 to 5611
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Regiao_Geografica      5570 non-null   object
#  1   Unidade_da_Federacao   5570 non-null   object
#  2   Municipio              5570 non-null   object
#  3   Codigo_do_Municipio    5570 non-null   object
#  4   Matriculas_Total       5570 non-null   object
#  5   Matriculas_Fem_Total   5570 non-null   object
#  6   MF_Nao_Declarada       5570 non-null   object
#  7   MF_Branca              5570 non-null   object
#  8   MF_Preta               5570 non-null   object
#  9   MF_Parda               5570 non-null   object
#  10  MF_Amarela             5570 non-null   object
#  11  MF_Indigena            5570 non-null   object
#  12  Matriculas_Masc_Total  5570 non-null   object
#  13  MM_Nao_Declarada       5570 non-null   object
# ...

# %%
df2.describe()
# Out:
#        Regiao_Geografica Unidade_da_Federacao   Municipio  \
# count               5570                 5570        5570
# unique                 5                   27        5297
# top            Nordeste         Minas Gerais   Bom Jesus
# freq                1794                  853           5
#
#         Codigo_do_Municipio  Matriculas_Total  Matriculas_Fem_Total  \
# count                  5570              5570                  5570
# unique                 5570              4075                  3255
# top                 1100015              1241                   342
# freq                      1                 7                    11
#
#         MF_Nao_Declarada  MF_Branca  MF_Preta  MF_Parda  MF_Amarela  \
# count               5570       5570      5570      5570        5570
# unique              1847       1830       611      2188         182
# top                   10        100         2        26           0
# ...

# %%
df2.isna().sum()
# Out:
# Regiao_Geografica        0
# Unidade_da_Federacao     0
# Municipio                0
# Codigo_do_Municipio      0
# Matriculas_Total         0
# Matriculas_Fem_Total     0
# MF_Nao_Declarada         0
# MF_Branca                0
# MF_Preta                 0
# MF_Parda                 0
# MF_Amarela               0
# MF_Indigena              0
# Matriculas_Masc_Total    0
# MM_Nao_Declarada         0
# MM_Branca                0
# MM_Preta                 0
# MM_Parda                 0
# MM_Amarela               0
# MM_Indigena              0
# dtype: int64

# %%
df2.groupby("Regiao_Geografica").count()
# Out:
#                    Unidade_da_Federacao  Municipio  Codigo_do_Municipio  \
# Regiao_Geografica
# Centro-Oeste                        467        467                  467
# Nordeste                           1794       1794                 1794
# Norte                               450        450                  450
# Sudeste                            1668       1668                 1668
# Sul                                1191       1191                 1191
#
#                    Matriculas_Total  Matriculas_Fem_Total  MF_Nao_Declarada  \
# Regiao_Geografica
# Centro-Oeste                    467                   467               467
# Nordeste                       1794                  1794              1794
# Norte                           450                   450               450
# Sudeste                        1668                  1668              1668
# Sul                            1191                  1191              1191
#
# ...

# %%
#checando para valores repetidos
df2['Codigo_do_Municipio'].groupby(df1['Regiao_Geografica']).count()
# Out:
# Regiao_Geografica
# Centro-Oeste      467
# Nordeste         1794
# Norte             450
# Sudeste          1668
# Sul              1191
# Name: Codigo_do_Municipio, dtype: int64

# %%
#checando para valores repetidos
df2['Codigo_do_Municipio'].groupby(df1['Regiao_Geografica']).nunique()
# Out:
# Regiao_Geografica
# Centro-Oeste      467
# Nordeste         1794
# Norte             450
# Sudeste          1668
# Sul              1191
# Name: Codigo_do_Municipio, dtype: int64

# %%
#Criando uma pivor table 
pivot_fem=df2.pivot_table(
    values=['Matriculas_Fem_Total','MF_Nao_Declarada','MF_Branca',
            'MF_Preta','MF_Parda','MF_Amarela','MF_Indigena'],
    index = 'Regiao_Geografica',
    aggfunc = sum
)

# %%
pivot_fem
# Out:
#                    MF_Amarela  MF_Branca  MF_Indigena  MF_Nao_Declarada  \
# Regiao_Geografica
# Centro-Oeste             5938     416259        25547            727134
# Nordeste                26889     879439        41337           2206288
# Norte                    5464     237865        81181            743489
# Sudeste                 31609    3992678        14673           2096410
# Sul                      9351    2001029        11662            678131
#
#                    MF_Parda  MF_Preta  Matriculas_Fem_Total
# Regiao_Geografica
# Centro-Oeste         589020     33194               1797092
# Nordeste            3393363    245858               6793174
# Norte               1256675     40774               2365448
# Sudeste             2764063    374112               9273545
# Sul                  389768     85978               3175919

# %% [markdown]
# ## Visualizações

# %%
fig, ax = plt.subplots()
Regiao_Geografica = pivot_fem.index
MF_Amarela = pivot_fem['MF_Branca']
ax.bar(Regiao_Geografica, MF_Amarela)
plt.show()
